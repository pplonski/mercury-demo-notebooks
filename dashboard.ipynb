# %% [raw]
# ---
# title: Finance dashboard
# description: Dashboard with financial data
# show-code: False
# params:
#     ticker:
#         input: select
#         value: TSLA
#         label: Select ticker
#         choices: [TSLA, COIN, MSFT, PLTR, SNOW, NFLX]
# ---

# %%
import yfinance as yf
import mplfinance as mpf
import mercury as mr

# %%
app = mr.App(title="Finance dashboard 💰", description="Dashboard with financial data")
# Out:
# mercury.App

# %% [markdown]
# # Historic stock price

# %%
ticker = mr.Select(label="Please select ticker", value="TSLA", 
                   choices=["TSLA", "COIN", "MSFT", "PLTR", "SNOW", "NFLX"])
# Out:
# mercury.Select

# %%
mr.Md(f"### Selected ticker: {ticker.value}")
# Out:
# ### Selected ticker: TSLA

# %%
history = yf.Ticker(ticker.value).history(period="3mo")

# %%
print(f"3 months low: {history.Low.min().astype(int)}")
print(f"3 months high: {history.High.max().astype(int)}")
# Out:
# 3 months low: 101
# 3 months high: 223

# %%
history.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-01-30 00:00:00-05:00  178.050003  179.770004  166.500000  166.660004
# 2023-01-31 00:00:00-05:00  164.570007  174.300003  162.779999  173.220001
# 2023-02-01 00:00:00-05:00  173.889999  183.809998  169.929993  181.410004
# 2023-02-02 00:00:00-05:00  187.330002  196.750000  182.610001  188.270004
# 2023-02-03 00:00:00-05:00  183.949997  199.000000  183.690002  189.979996
#
#                               Volume  Dividends  Stock Splits
# Date
# 2023-01-30 00:00:00-05:00  230878800        0.0           0.0
# 2023-01-31 00:00:00-05:00  196813500        0.0           0.0
# 2023-02-01 00:00:00-05:00  213806300        0.0           0.0
# 2023-02-02 00:00:00-05:00  217448300        0.0           0.0
# 2023-02-03 00:00:00-05:00  231684200        0.0           0.0

# %%
mpf.plot(history, type='candle', mav=(7),figratio=(18,10))
