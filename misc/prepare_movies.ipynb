# %%
import pandas as pd

# %%
df = pd.read_csv("/home/piotr/Downloads/all_movies.csv")

# %%
df.head()
# Out:
#    Unnamed: 0    ID     imdbID  \
# 0           1  4972  tt0004972
# 1           2  6206  tt0006206
# 2           3  6864  tt0006864
# 3           4  9470  tt0009470
# 4           5  9968  tt0009968
#
#                                               Title  Year   Rating_m  Runtime  \
# 0                             The Birth of a Nation  1915  Not Rated      165
# 1                                      Les vampires  1915  Not Rated      399
# 2  Intolerance: Love's Struggle Throughout the Ages  1916  Not Rated      197
# 3                                      Over the Top  1918        NaN        0
# 4    Broken Blossoms or The Yellow Man and the Girl  1919  Not Rated       90
#
#                       Genre    Released         Director  ... Meter  Reviews  \
# 0   Drama, History, Romance  1915-03-03    D.W. Griffith  ...   100       38
# 1  Action, Adventure, Crime  1915-11-13  Louis Feuillade  ...   100       13
# 2            Drama, History  1916-09-05    D.W. Griffith  ...    96       28
# 3                Drama, War  1918-03-31    Wilfrid North  ...    36       11
# 4            Drama, Romance  1919-10-20    D.W. Griffith  ...    95       20
#
#    Fresh Rotten userMeter  userRating  userReviews  BoxOffice  \
# 0     38      0      58.0         3.3       4034.0        NaN
# 1     13      0      85.0         3.8       2075.0        NaN
# 2     27      1      78.0         3.8       4604.0        NaN
# 3      4      7      51.0         2.8      44707.0        NaN
# 4     19      1      72.0         3.7       3651.0        NaN
#
#           Production                                               Cast
# 0           Gravitas  Lillian Gish, Mae Marsh, Henry B. Walthall, Mi...
# 1                NaN  Musidora, Édouard Mathé, Marcel Lévesque, Jean...
# 2  Cohen Media Group  Lillian Gish, Spottiswoode Aitken, Mary Alden,...
# 3                NaN  Arthur Guy Empey, Lois Meredith, James Morriso...
# 4      Kino on Video  Lillian Gish, Richard Barthelmess, Donald Cris...
#
# [5 rows x 27 columns]

# %% [raw]
#   "Tomato Meter" = "Meter",
#   "Numeric Rating" = "Rating",
#   "Number of reviews" = "Reviews",
#   "Dollars at box office" = "BoxOffice",
#   "Year" = "Year",
#   "Length (minutes)" = "Runtime"

# %%
df = df[
    [
        "ID",
        "Title",
        "Year",
        "Runtime",
        "Meter",
        "Rating",
        "Reviews",
        "Oscars",
        "Genre",
        "Director",
        "Cast",
        "BoxOffice",
    ]
][df.BoxOffice > 0]

# %%
df.to_csv("movies_data.csv", index=False)

# %%
df2.shape
# Out:
# (1641, 8)

# %%
p = figure(width=800, height=400)

# add a circle renderer with a size, color, and alpha
p.circle(df2.userRating, df2.Reviews, size=4, color="navy", alpha=0.5)


# show the results
show(p)
# Out:
#   <div class="bk-root" id="34c8f6ea-47a0-4cbf-a5b2-b3646e05e78d" data-root-id="2160"></div>

# %%
from bokeh.plotting import figure, output_notebook, show

# output to static HTML file
# output_file("line.html")
output_notebook(hide_banner=True)

p = figure(width=800, height=400)

# add a circle renderer with a size, color, and alpha
p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="navy", alpha=0.5)
p.circle([1, 2, 3], [6, 4, 5], size=20, color="gold", alpha=0.5)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="c37a376c-f58d-468e-b10e-53135d8bd939" data-root-id="1664"></div>

# %%
all_movies <- inner_join(omdb, tomatoes, by = "ID") %>%
  filter(Reviews >= 10) %>%
  select(ID, imdbID, Title, Year, Rating_m = Rating.x, Runtime, Genre, Released,
    Director, Writer, imdbRating, imdbVotes, Language, Country, Oscars,
    Rating = Rating.y, Meter, Reviews, Fresh, Rotten, userMeter, userRating, userReviews,
    BoxOffice, Production, Cast)
# Out:
#   File "/tmp/ipykernel_7790/612327365.py", line 1
#     all_movies <- inner_join(omdb, tomatoes, by = "ID") %>%
#                                                          ^
# SyntaxError: invalid syntax

# %%
tom
# Out:
#             ID Image  Rating  Meter  Reviews  Fresh  Rotten Consensus  \
# 0            4  None     NaN   17.0      NaN    NaN     NaN      None
# 1            5  None     NaN   39.0      NaN    NaN     NaN      None
# 2           10  None     NaN   20.0      NaN    NaN     NaN      None
# 3           75  None     NaN    NaN      NaN    NaN     NaN      None
# 4           89  None     NaN    0.0      NaN    NaN     NaN      None
# ...        ...   ...     ...    ...      ...    ...     ...       ...
# 76425  3505950  None     NaN    NaN      1.0    0.0     1.0      None
# 76426  3511542  None     NaN    NaN      3.0    3.0     0.0      None
# 76427  3518988  None     NaN    NaN      1.0    1.0     0.0      None
# 76428  3548442  None     NaN    NaN      2.0    0.0     2.0      None
# 76429  3589450  None     NaN    NaN      1.0    0.0     1.0      None
#
#        userMeter  userRating  userReviews DVD  BoxOffice  \
# 0           17.0         2.8        215.0            NaN
# 1           39.0         3.1        169.0            NaN
# 2           20.0         NaN        109.0            NaN
# 3            NaN         NaN          4.0            NaN
# 4            0.0         NaN         50.0            NaN
# ...          ...         ...          ...  ..        ...
# 76425       43.0         NaN         42.0            NaN
# 76426       80.0         NaN          6.0            NaN
# 76427        NaN         NaN          NaN            NaN
# 76428        NaN         NaN          NaN            NaN
# 76429        NaN         4.0         29.0            NaN
#
#                      Production  \
# 0
# 1
# 2
# 3
# 4
# ...                         ...
# 76425  China Lion Entertainment
# 76426          China Lion Films
# 76427                      None
# 76428                      None
# 76429          CJ Entertainment
#
#                                                  Website  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 76425              http://www.beijinglovestorymovie.com/
# 76426                     http://www.thatdemonwithin.com
# 76427                        http://live.harmontown.com/
# 76428                                               None
# 76429  http://www.cgvcinemas.com/movie/detail.asp?sta...
#
#                          lastUpdated
# 0                2012-10-01 00:00:00
# 1                2012-10-01 00:00:00
# 2                2012-10-04 00:00:00
# 3                2012-09-27 00:00:00
# 4                2012-10-01 00:00:00
# ...                              ...
# 76425  2014-02-13 11:44:27.180000000
# 76426  2014-03-05 17:16:01.200000000
# 76427  2014-04-03 09:10:11.390000000
# 76428  2014-03-31 03:24:10.637000000
# 76429  2014-04-03 10:09:57.423000000
#
# [76430 rows x 16 columns]

# %%
# Out:
#             ID     imdbID                                             Title  \
# 0         4972  tt0004972                             The Birth of a Nation
# 1         6206  tt0006206                                      Les vampires
# 2         6864  tt0006864  Intolerance: Love's Struggle Throughout the Ages
# 3         9470  tt0009470                                      Over the Top
# 4         9968  tt0009968    Broken Blossoms or The Yellow Man and the Girl
# ...        ...        ...                                               ...
# 12564  3210686  tt3210686                                        Son of God
# 12565  3228928  tt3228928                 The Prime Ministers: The Pioneers
# 12566  3234082  tt3234082                                          12-12-12
# 12567  3263614  tt3263614                       Kumiko, the Treasure Hunter
# 12568  3404140  tt3404140                                      The Attorney
#
#        Year     Rating  Runtime                     Genre    Released  \
# 0      1915  Not Rated    165.0   Drama, History, Romance  1915-03-03
# 1      1915  Not Rated    399.0  Action, Adventure, Crime  1915-11-13
# 2      1916  Not Rated    197.0            Drama, History  1916-09-05
# 3      1918       None      0.0                Drama, War  1918-03-31
# 4      1919  Not Rated     90.0            Drama, Romance  1919-10-20
# ...     ...        ...      ...                       ...         ...
# 12564  2014      PG-13    138.0                     Drama  2014-02-28
# 12565  2013       None      0.0               Documentary  2013-10-18
# 12566  2013          R    105.0               Documentary  2013-11-01
# 12567  2014       None    105.0                     Drama  2014-01-20
# 12568  2013       None    127.0                     Drama  2014-02-07
#
#                   Director                                             Writer  \
# 0            D.W. Griffith  Thomas F. Dixon Jr. (adapted from his novel: "...
# 1          Louis Feuillade                                    Louis Feuillade
# 2            D.W. Griffith      D.W. Griffith (scenario), Anita Loos (titles)
# 3            Wilfrid North  Robert Gordon Anderson (scenario), Arthur Guy ...
# 4            D.W. Griffith  Thomas Burke (adapted from a story by), D.W. G...
# ...                    ...                                                ...
# 12564  Christopher Spencer  Richard Bedser, Christopher Spencer, Colin Swa...
# 12565        Richard Trank            Marvin Hier, Richard Trank (screenplay)
# 12566         Amir Bar-Lev                                               None
# 12567        David Zellner                      David Zellner, Nathan Zellner
# 12568        Woo-seok Yang                       Yoon Hyeon-ho, Woo-seok Yang
#
#                                                     Cast  Metacritic  \
# 0      Lillian Gish, Mae Marsh, Henry B. Walthall, Mi...         NaN
# 1      Musidora, Édouard Mathé, Marcel Lévesque, Jean...         NaN
# 2      Lillian Gish, Spottiswoode Aitken, Mary Alden,...         NaN
# 3      Arthur Guy Empey, Lois Meredith, James Morriso...         NaN
# 4      Lillian Gish, Richard Barthelmess, Donald Cris...         NaN
# ...                                                  ...         ...
# 12564  Sebastian Knapp, Paul Knops, Darcie, David Rin...        37.0
# 12565  Sandra Bullock, Robert Cait, Michael Douglas, ...        43.0
# 12566  Jon Bon Jovi, Eric Clapton, Roger Daltrey, Mic...        54.0
# 12567  Rinko Kikuchi, Nobuyuki Katsube, Shirley Venar...        87.0
# 12568  Yeong-ae Kim, Do Won Kwak, Dal-su Oh, Kang-ho ...        55.0
#
#        imdbRating  imdbVotes         Language      Country  \
# 0             6.9    13793.0             None          USA
# 1             6.6     2502.0           French       France
# 2             8.0     8673.0             None          USA
# 3             NaN        NaN             None          USA
# 4             7.7     5821.0             None          USA
# ...           ...        ...              ...          ...
# 12564         5.4     5274.0  English, Hebrew          USA
# 12565         5.7        9.0          English          USA
# 12566         5.8       90.0          English          USA
# 12567         7.9       35.0             None          USA
# 12568         7.8      237.0           Korean  South Korea
#
#                       Awards                    lastUpdated  Oscars
# 0                     1 win.  2014-03-31 02:13:23.440000000       0
# 1              1 nomination.  2014-03-07 00:05:37.133000000       0
# 2                     1 win.  2014-03-27 01:05:04.920000000       0
# 3                       None            2014-01-31 00:00:00       0
# 4                     1 win.  2014-03-24 01:47:25.100000000       0
# ...                      ...                            ...     ...
# 12564                   None  2014-03-21 00:02:34.907000000       0
# 12565                   None  2014-03-15 00:06:39.827000000       0
# 12566                   None  2014-03-21 00:02:07.580000000       0
# 12567  1 win & 1 nomination.            2014-01-28 00:00:00       0
# 12568         3 nominations.  2014-03-30 01:47:26.123000000       0
#
# [12569 rows x 19 columns]
