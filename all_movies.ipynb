# %% [raw]
# ---
# title: Movies Explorer
# description: 🎥🎬 Explore movies data with Mercury🍿
# author: Piotr
# show-code: False
# show-prompt: False
# params:
#     reviews:
#         input: slider
#         label: Minimum number of reviews
#         value: 150
#         min: 10
#         max: 300
#     year:
#         input: range
#         label: Year released
#         value: [1940, 2014]
#         min: 1940
#         max: 2014
#     min_oscars:
#         input: slider
#         label: Minimum number of Oscars wins
#         value: 0
#         min: 0
#         max: 4
#     box_office:
#         input: range
#         label: Box Office (millions $)
#         value: [0, 800]
#         min: 0
#         max: 800
#     genre:
#         input: select
#         label: Genre
#         multi: False
#         value: All
#         choices: [All, Action, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, History, Horror, Music, Musical, Mystery, Romance, Sci-Fi, Short, Sport, Thriller, War, Western]
#     x_axis:
#         input: select
#         label: X-axis variable
#         multi: False
#         value: Meter
#         choices: [Meter, Rating, Reviews, BoxOffice, Year, Runtime]
#     y_axis:
#         input: select
#         label: Y-axis variable
#         multi: False
#         value: Reviews
#         choices: [Meter, Rating, Reviews, BoxOffice, Year, Runtime]
# ---

# %% [markdown]
# # Movies Explorer🎥🎬🍿

# %%
import pandas as pd
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure, output_notebook, show

# %%
output_notebook(hide_banner=True)

# %%
reviews = 10
year = [1980, 2014]
min_oscars = 0
box_office = [0, 800]
genre = "All"
x_axis = "Meter"
y_axis = "Reviews"

# %%
df = pd.read_csv("/home/piotr/sandbox/mercury-demo-notebooks/movies_data.csv")

# %%
df_filtered = df[
    (df.Reviews >= reviews)
    & (df.Year >= year[0])
    & (df.Year <= year[1])
    & (df.Oscars >= min_oscars)
    & (df.BoxOffice >= box_office[0] * 1e6)
    & (df.BoxOffice <= box_office[1] * 1e6)
    & (df.Genre.str.contains(genre) if genre != "All" else True)
]
source_no_oscar = ColumnDataSource(data=df_filtered[df_filtered.Oscars == 0])
source_oscar = ColumnDataSource(data=df_filtered[df_filtered.Oscars > 0])

# %%
tooltips = [("Title", "@Title"), ("Year", "@Year"), ("$", "@BoxOffice")]
p = figure(
    width=800, height=400, tooltips=tooltips, x_axis_label=x_axis, y_axis_label=y_axis
)
p.circle(x=x_axis, y=y_axis, source=source_no_oscar, size=5, color="grey", alpha=0.5)
p.circle(x=x_axis, y=y_axis, source=source_oscar, size=7, color="gold", alpha=1)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="dcfa674a-a93d-48e5-a1df-cc7eb056209a" data-root-id="1004"></div>

# %% [markdown]
# ### Selected movies

# %%
from IPython.display import Markdown as md

md(
    f"""
<div class="alert alert-block alert-success">
<b>Success:</b> Selected {df_filtered.shape[0]} movies.
</div>
"""
)
# Out:
# <div class="alert alert-block alert-success">
# <b>Success:</b> Selected 4156 movies.
# </div>

# %% [markdown]
# Sample of selected movies:

# %%
df_filtered.head(10)
# Out:
#        ID                    Title  Year  Runtime  Meter  Rating  Reviews  \
# 7   35423           Kate & Leopold  2001      118     50     5.3      126
# 33  82971  Raiders of the Lost Ark  1981      115     95     9.1       65
# 34  83658             Blade Runner  1982      117     91     8.4       96
# 35  86022               Nostalghia  1983      125     82     7.6       11
# 36  86250                 Scarface  1983      170     88     7.4       59
# 37  86879                  Amadeus  1984      160     95     8.6       79
# 38  88119              Silver City  1984      101     48     5.5      126
# 39  90015                    Shoah  1985      566    100     9.1       24
# 40  92099                  Top Gun  1986      110     55     5.8       47
# 41  94868                 Chocolat  1988      105     70     7.0       10
#
#     Oscars                      Genre           Director  \
# 7        0   Comedy, Fantasy, Romance      James Mangold
# 33       4          Action, Adventure   Steven Spielberg
# 34       0    Drama, Sci-Fi, Thriller       Ridley Scott
# 35       0                      Drama   Andrei Tarkovsky
# 36       0               Crime, Drama     Brian De Palma
# 37       8    Biography, Drama, Music       Milos Forman
# 38       0                      Drama  Sophia Turkiewicz
# 39       0  Documentary, History, War    Claude Lanzmann
# 40       1     Action, Drama, Romance         Tony Scott
# 41       0                      Drama       Claire Denis
#
#                                                  Cast   BoxOffice
# 7   Meg Ryan, Hugh Jackman, Liev Schreiber, Brecki...  47100000.0
# 33  Harrison Ford, Karen Allen, Paul Freeman, Rona...   3100000.0
# 34  Harrison Ford, Rutger Hauer, Sean Young, Edwar...   1200000.0
# 35  Oleg Yankovskiy, Erland Josephson, Domiziana G...      5200.0
# 36  Al Pacino, Steven Bauer, Michelle Pfeiffer, Ma...    700000.0
# 37  F. Murray Abraham, Tom Hulce, Elizabeth Berrid...     86800.0
# 38  Gosia Dobrowolska, Ivar Kants, Anna Maria Mont...    900000.0
# 39  Simon Srebnik, Michael Podchlebnik, Motke Zaid...     15600.0
# 40  Tom Cruise, Kelly McGillis, Val Kilmer, Anthon...   3000000.0
# 41  Isaach De Bankolé, Giulia Boschi, François Clu...    200000.0
